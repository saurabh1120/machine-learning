# %%
import pandas as pd 
import numpy as np 

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("Iris-f.csv")

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              NaN           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %%
df.count
# Out:
# <bound method DataFrame.count of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              NaN           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
df.count()
# Out:
# SepalLengthCm    148
# SepalWidthCm     149
# PetalLengthCm    149
# PetalWidthCm     150
# Species          148
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 4             NaN           3.6            1.4           0.2  Iris-setosa
# 7             5.0           NaN            NaN           0.2  Iris-setosa
# 10            5.4           3.7            1.5           0.2          NaN
# 20            NaN           3.4            1.7           0.2  Iris-setosa
# 51            6.4           3.2            4.5           1.5          NaN

# %%
df1=df.copy(deep=True)

# %%
df1.dropna(axis=0)#droping of null values
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [145 rows x 5 columns]

# %%
df1.dropna(axis=0,inplace=True)#droping of null values

# %%
df1.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
len(df1)
# Out:
# 145

# %%
df1.dropna(axis=0,how="all",inplace=True)#droping of null values

# %%
df1.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
len(df1)
# Out:
# 145

# %%
df1.dropna(axis=0,thresh=4,inplace=True)#droping of null values

# %%
df1.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [145 rows x 5 columns]

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              NaN           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(axis=0,thresh=4,inplace=True)#droping of null values

# %%
df.isna().sum()
# Out:
# SepalLengthCm    2
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          2
# dtype: int64

# %%
#thresh is checking non NA value from the given csv

# %%
len(df)
# Out:
# 149

# %%
df.dropna(axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# dtype: int64

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
#del df1["petaWidhcm"]

# %% [markdown]
# ## Impute the values

# %%
m=df1["SepalLengthCm"].mean()
m
# Out:
# 5.857241379310346

# %% [markdown]
# df1=df1.fillna(m)

# %%
df1.fillna(0)

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df1=df1.fillna(0)

# %%
df1.head(10)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# 12            4.8           3.0            1.4           0.1  Iris-setosa

# %%
df1=df1.fillna(method="ffill")

# %%
df.iloc[[4,7,10,20,51],:]
# Out:
#     SepalWidthCm  PetalLengthCm  PetalWidthCm
# 4            3.6            1.4           0.2
# 8            2.9            1.4           0.2
# 11           3.4            1.6           0.2
# 21           3.7            1.5           0.4
# 52           3.1            4.9           1.5

# %%
dl = pd.read_csv("Iris-f.csv")

# %%
dl
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              NaN           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dl.iloc[[4,7,20,51],:]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 4             NaN           3.6            1.4           0.2  Iris-setosa
# 7             5.0           NaN            NaN           0.2  Iris-setosa
# 20            NaN           3.4            1.7           0.2  Iris-setosa
# 51            6.4           3.2            4.5           1.5          NaN

# %%
df1=df1.fillna(method="ffill")
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [145 rows x 5 columns]

# %%
df1.head(10)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# 12            4.8           3.0            1.4           0.1  Iris-setosa

# %%
df2=df.iloc[:,0:4]
df2.head()
# Out:
#    SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0           3.5            1.4           0.2
# 1           3.0            1.4           0.2
# 2           3.2            1.3           0.2
# 3           3.1            1.5           0.2
# 4           3.6            1.4           0.2

# %%
df2.shape
# Out:
# (149, 3)

# %%
a=SimpleImputer()

# %%
a.fit_transform(df2)
# Out:
# array([[3.5, 1.4, 0.2],
#        [3. , 1.4, 0.2],
#        [3.2, 1.3, 0.2],
#        [3.1, 1.5, 0.2],
#        [3.6, 1.4, 0.2],
#        [3.9, 1.7, 0.4],
#        [3.4, 1.4, 0.3],
#        [2.9, 1.4, 0.2],
#        [3.1, 1.5, 0.1],
#        [3.7, 1.5, 0.2],
#        [3.4, 1.6, 0.2],
#        [3. , 1.4, 0.1],
#        [3. , 1.1, 0.1],
#        [4. , 1.2, 0.2],
#        [4.4, 1.5, 0.4],
#        [3.9, 1.3, 0.4],
#        [3.5, 1.4, 0.3],
#        [3.8, 1.7, 0.3],
#        [3.8, 1.5, 0.3],
#        [3.4, 1.7, 0.2],
#        [3.7, 1.5, 0.4],
#        [3.6, 1. , 0.2],
#        [3.3, 1.7, 0.5],
#        [3.4, 1.9, 0.2],
#        [3. , 1.6, 0.2],
#        [3.4, 1.6, 0.4],
#        [3.5, 1.5, 0.2],
#        [3.4, 1.4, 0.2],
#        [3.2, 1.6, 0.2],
#        [3.1, 1.6, 0.2],
#        [3.4, 1.5, 0.4],
#        [4.1, 1.5, 0.1],
#        [4.2, 1.4, 0.2],
#        [3.1, 1.5, 0.1],
#        [3.2, 1.2, 0.2],
#        [3.5, 1.3, 0.2],
#        [3.1, 1.5, 0.1],
#        [3. , 1.3, 0.2],
# ...
